# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random
import time
import locale

locale.setlocale(locale.LC_ALL, 'turkish')
print("Kumanda Başlatılıyor...")
time.sleep(1)


class kumanda():
    def __init__(self,tv_durum = "Kapalı", tv_ses = 0, kanal_listesi = ["Show"], aktif_kanal = "Show"):
        self.tv_durum = tv_durum
        self.tv_ses = tv_ses
        self.kanal_listesi = kanal_listesi
        self.aktif_kanal = aktif_kanal
    def tv_ac(self):
        if (self.tv_durum == "Kapalı" ):
            print("Televizyon Açılıyor")
            time.sleep(1)
            self.tv_durum = "Açık"
        elif(self.tv_durum == "Açık"):
            print("Televizyon Zaten Açık")
        
    def tv_kapa():
        if (self.tv_durum == "Kapalı" ):
            print("Televizyon Zaten Kapalı")
        elif(self.tv_durum == "Açık"):
            print("Televizyon Kapatılıyor")
            time.sleep(1)
            self.tv_durum = "Kapalı"

    
    def ses_ayar(self):
        print("Ses Ayarlarına Giriş Yapılıyor")
        time.sleep(1)
        
        while True:
            girdi = input("Sesi Yükseltmek İçin '+' Azaltmak İçin '-' Tuşuna Basınız. Çıkmak İçin 'çıkış' Yazınız.")
            if (girdi == "+"):
                if (self.tv_ses != 0):
                    self.tv_ses += 10
                    print("Ses Seviyesi: ", self.tv_ses)
            elif girdi == "-":
                if (self.tv_ses != 100):
                    self.tv_ses -= 10
                    print("Ses Seviyesi: ", self.tv_ses)
            else:
                print("Ses Güncellendi: ", self.tv_ses)
                time.sleep(1)
                break
    
    def kanal_ekle(self):
        print("Kanal Ekleniyor")
        time.sleep(1)
        self.kanal_listesi.append(kanal_ismi)
        print("Kanal Eklendi")
        
    def kanalsayisi_ogren(self):
        print("Kanal Sayısı Belirleniyor")
        time.sleep(1)
        return len(self.kanal_listesi)
    
    def kanala_gec(self):
        print("Rastgele Bir Kanala Geçiliyor")
        time.sleep(1)
        rastgele = random.randint(0,len(self.kanal_listesi)-1)
        self.aktif_kanal = self.kanal_listesi[rastgele]
        print("Aktif Kanal: ", self.aktif_kanal)
    
    def televizyon_bilgisi(self):
        print("Televizyon Bilgisi Getiriliyor")
        time.sleep(1)
        return "Televizyon Durumu: {} \n Televizyon Ses: {} \n Kanal Listesi: {} \n Aktif Kanal: {} \n".format(self.tv_durum, self.tv_ses,self.kanal_listesi,self.aktif_kanal)

print("""
Kumanda
1. Tv Aç
2. Tv Kapat
3. Ses Ayarları
4. Kanal Ekle
5. Kanal Sayısını Öğrenme
6. Rastgele Kanala Geçme
7. Televizyon Bilgileri
Çıkmak İçin 'q' tuşuna basınız
      """)

while True:
    islem = input("Yapmak istediğiniz işlemi seçiniz: ")
    if(islem == "1"):
        kumanda.tv_ac
    elif (islem == "2"):
        kumanda.tv_kapa
    elif (islem == "3"):
        kumanda.ses_ayar
    elif (islem == "4"):
        kanal_isim = input("Eklemek istediğiniz Kanal İsimlerini giriniz (',' ile ayırmaya özen gösteriniz): ")
        kanal_listesi = kanal_isim.split(",")
        for i in kanal_listesi:
            kumanda.kanal_ekle(i)
    elif (islem == "5"):
        print("Kanal Sayısı: ", len(kumanda.kanal_listesi))
    elif (islem == "6"):
        kumanda.kanala_gec()
    elif (islem == "7"):
        print(kumanda.televizyon_bilgisi)
    elif( islem == "q"):
        print("Çıkış Yapılıyor")
        time.sleep(1)
        break
    else:
        print("Bilinmeyen Girdi Lütfen Tekrar Deneyiniz.")
# Out:
# Kumanda Başlatılıyor...
#
# Kumanda
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
# Çıkmak İçin 'q' tuşuna basınız
#
# Bilinmeyen Girdi Lütfen Tekrar Deneyiniz.
# <function kumanda.televizyon_bilgisi at 0x00000218DAE827A0>
# Çıkış Yapılıyor
